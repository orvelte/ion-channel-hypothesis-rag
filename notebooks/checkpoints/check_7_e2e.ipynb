# %% [markdown]
# # Check 7 — E2E
#
# End-to-end benchmark: 5 held-out queries, full pipeline, failure taxonomy (retrieval failure / generation failure / data gap).
#
# > Run `src/evaluation/stage_7_e2e.py` first to generate the artifact this notebook analyses.

# %%
import json
from pathlib import Path
import yaml

with open("../../configs/pipeline.yaml") as f:
    config = yaml.safe_load(f)

artifact_dir = Path(config["paths"]["evaluation"]) / f"stage_{n}"
print(f"Artifact dir: {artifact_dir}")

# %% [markdown]
# ## Results
#
# _Load and visualise the artifact produced by the evaluation script._
