# %% [markdown]
# # Check 6 — Outputs
#
# Output evaluation: parse success rate, factual grounding trace, mechanistic plausibility, novelty vs verbatim retrieval.
#
# > Run `src/evaluation/stage_6_outputs.py` first to generate the artifact this notebook analyses.

# %%
import json
from pathlib import Path
import yaml

with open("../../configs/pipeline.yaml") as f:
    config = yaml.safe_load(f)

artifact_dir = Path(config["paths"]["evaluation"]) / f"stage_{n}"
print(f"Artifact dir: {artifact_dir}")

# %% [markdown]
# ## Results
#
# _Load and visualise the artifact produced by the evaluation script._
