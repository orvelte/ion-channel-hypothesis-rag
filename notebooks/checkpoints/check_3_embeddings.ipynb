# %% [markdown]
# # Check 3 — Embeddings
#
# Embedding quality: nearest-neighbour spot check, known-pair retrieval (e.g. lamotrigine → SCN1A), cosine score distribution.
#
# > Run `src/evaluation/stage_3_embeddings.py` first to generate the artifact this notebook analyses.

# %%
import json
from pathlib import Path
import yaml

with open("../../configs/pipeline.yaml") as f:
    config = yaml.safe_load(f)

artifact_dir = Path(config["paths"]["evaluation"]) / f"stage_{n}"
print(f"Artifact dir: {artifact_dir}")

# %% [markdown]
# ## Results
#
# _Load and visualise the artifact produced by the evaluation script._
